# %% [markdown]
# # Experimental results

# %%
import matplotlib.pyplot as plt
import numpy as np

def line_plot_individual(k,x_values, y_values_1,y_values_2,y_values_3,y_values_4):
    plt.plot(x_values, y_values_1, label='Encryption', linestyle='-', marker='o', color='blue')
    plt.plot(x_values, y_values_2, label='Distances', linestyle='--', marker='s', color='green')
    plt.plot(x_values, y_values_3, label='Comparisons', linestyle='-.', marker='^', color='red')
    plt.plot(x_values, y_values_4, label='Sorting', linestyle=':', marker='d', color='purple')


    plt.xlabel('Training samples')
    plt.ylabel('Time (s)')
    plt.title(f'k={k}')

    plt.xticks(np.arange(min(x_values), max(x_values) + 1, 1))
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.figure(figsize=(8, 6))
    
    plt.show()

# %%
def stacked_bar_plot(k, x_values, y_values_1, y_values_2, y_values_3, y_values_4):
    total = np.array([v1 + v2 + v3 + v4 for v1, v2, v3, v4 in zip(y_values_1, y_values_2, y_values_3, y_values_4)])
    percent1 = np.array([v1 / t * 100 for v1, t in zip(y_values_1, total)])
    percent2 = np.array([v2 / t * 100 for v2, t in zip(y_values_2, total)])
    percent3 = np.array([v3 / t * 100 for v3, t in zip(y_values_3, total)])
    percent4 = np.array([v4 / t * 100 for v4, t in zip(y_values_4, total)])

    plt.figure(figsize=(8, 6))

    colors = ['lightblue', '#8bc34a', '#ff5722', '#ff9800', '#9c27b0']

    plt.bar(x_values, percent1, label='Encryption', color=colors[0])
    plt.bar(x_values, percent2, bottom=percent1, label='Distances', color=colors[1])
    plt.bar(x_values, percent3, bottom=percent1 + percent2, label='Comparisons', color=colors[2])
    plt.bar(x_values, percent4, bottom=percent1 + percent2 + percent3, label='Sorting', color=colors[3])

    plt.xlabel('Training samples')
    plt.ylabel('Percentage')
    plt.title(f'k={k}')
    plt.ylim(0, 104)
    plt.xticks(np.arange(min(x_values), max(x_values) + 1, 1))
    plt.legend(loc='upper right')


    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)


    plt.tick_params(axis='x', which='both', bottom=False)
    plt.tick_params(axis='y', which='both', left=False)


    plt.grid(axis='y', linestyle='--', alpha=0.7)

    if k == 3:
        show_percent_list = [0,1,2,3,4,5,6,7]
    elif k == 5:
        show_percent_list = [0,1,2,3,4,5]
    else:
        show_percent_list = [0,1,2,3]
        
    
    for i, v in enumerate(x_values):
        y_offset = 0
        for j, percent in enumerate([percent1, percent2, percent3, percent4]):
            if j in [1,2,3]:
                plt.text(v, y_offset + percent[i] / 2, f'{percent[i]:.1f}%', ha='center', va='center', fontsize=8,weight='bold',rotation=0)
            if i in show_percent_list and j == 0:
                 plt.text(v, y_offset + percent[i] / 2, f'{percent[i]:.1f}%', ha='center', va='center', fontsize=8,weight='bold',rotation=0)
                
            y_offset += percent[i]

    plt.show()

# %% [markdown]
# ## k=3

# %%
x_values = list(range(4, 18))
y_values_1 = [27.65, 32.48, 38.30, 44.10, 49.25, 55.12, 61.43, 69.97, 74.38, 77.72, 88.22, 98.76, 101.88, 109.25]
y_values_2 = [43.17, 60.83, 81.43, 107.64, 126.29, 158.87, 189.95, 223.80, 260.21, 289.35, 342.71, 350.82, 401.08, 477.50]
y_values_3 = [137.45, 236.17, 378.14, 631.44, 896.72, 1346.66, 1691.99, 2410.46, 3045.39, 3742.85, 4771.19, 5928.94, 7184.19, 9217.18]
y_values_4 = [30.34, 63.12, 140.56, 287.40, 537.80, 1057.84, 1643.92, 2813.97, 4355.43, 6690.94, 10344.59, 15406.11, 22740.85, 39087.76]
y_values_5 =[0.83, 0.64, 0.61, 0.61, 0.44, 0.41, 0.36, 0.41, 0.38, 0.41, 0.51, 0.45, 0.49, 0.42]

line_plot_individual(3,x_values,y_values_1,y_values_2,y_values_3,y_values_4)
stacked_bar_plot(3, x_values, y_values_1,y_values_2,y_values_3,y_values_4)

# %% [markdown]
# ## k=5

# %%
x_values = list(range(6, 18))
y_values_1 = [36.88, 43.78, 46.85, 56.57, 58.8, 65.75, 72.73, 78.46, 85.08, 96.37, 99.91, 107.81]
y_values_2 = [78.63, 108.71, 123.53, 164.15, 186.09, 217.72, 259.31, 290.81, 289.55, 328.74, 424.49, 467.07]
y_values_3 = [364.27, 642.29, 808.57, 1314.27, 1639.15, 2321.5, 2929.91, 3870.28, 4548.8, 5796.78, 7220.89, 9409.2]
y_values_4 = [149.43, 322.8, 511.89, 1064.16, 1619.96, 3406.56, 4158.76, 7000.32, 10244.8, 15023.9, 22849.4, 38881.3]
y_values_5 = [0.66, 0.6, 0.45, 0.49, 0.36, 0.39, 0.38, 0.49, 0.55, 0.48, 0.52, 0.47]


line_plot_individual(5,x_values,y_values_1,y_values_2,y_values_3,y_values_4)
stacked_bar_plot(5, x_values, y_values_1,y_values_2,y_values_3,y_values_4)

# %% [markdown]
# ## k=7

# %%
import matplotlib.pyplot as plt

x_values = list(range(8, 18))
y_values_1 = [51.57, 56.84, 62.97, 72.33, 76.74, 77.98, 84.71, 95.03, 98.64, 106.5]
y_values_2 = [124.22, 158.03, 185.21, 234.65, 263.84, 288.39, 287.05, 419.5, 424.04, 475.32]
y_values_3 = [897.11, 1299.24, 1750.43, 2495.93, 3229.59, 3670.73, 4552.67, 6126.68, 7236.6, 9317.52]
y_values_4 = [575.1, 1038.68, 1690.91, 2981.57, 4363.22, 6758.53, 10048.4, 16120, 22699.9, 38582.4]
y_values_5 = [0.64, 0.54, 0.48, 0.5, 0.44, 0.55, 0.58, 0.62, 0.66, 0.56]


line_plot_individual(7,x_values,y_values_1,y_values_2,y_values_3,y_values_4)
stacked_bar_plot(7, x_values, y_values_1,y_values_2,y_values_3,y_values_4)

# %% [markdown]
# ## Plots for all values of k

# %%
def line_plot_general(x_values, y_values_1,y_values_2,y_values_3,title):
    plt.plot(x_values, y_values_1, label='k=3', linestyle='-', marker='o', color='blue')
    plt.plot(x_values, y_values_2, label='k=5', linestyle='--', marker='s', color='green')
    plt.plot(x_values, y_values_3, label='k=7', linestyle='-.', marker='^', color='red')


    plt.xlabel('Training samples')
    plt.ylabel('Time (s)')
    plt.title(title)


    plt.legend()
    plt.xticks(np.arange(min(x_values), max(x_values) + 1, 1))
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.figure(figsize=(8, 6))
    plt.show()

# %% [markdown]
# ### Total

# %%
x_values = list(range(8, 18))
k3_total = [1610.48, 2618.88, 3587.64, 5518.59, 7735.78, 10801.27, 15547.22, 21785.07, 30428.48, 48892.10]
k5_total = [1491.29, 2599.64, 3504.36, 6011.92, 7421.09, 11240.36, 15168.78, 21246.27, 30595.21, 48820.71]
k7_total = [1648.64, 2553.33, 3690, 5784.98, 7933.83, 10796.18, 14973.41, 22761.83, 30459.84, 48482.3]

line_plot_general(x_values, k3_total, k5_total, k7_total, 'Total computation time')

# %% [markdown]
# ### Encryption

# %%
x_values = list(range(8, 18))
k3_total = [49.25, 55.12, 61.43, 69.97, 74.38, 77.72, 88.22, 98.76, 101.88, 109.25] 
k5_total = [46.85, 56.57, 58.8, 65.75, 72.73, 78.46, 85.08, 96.37, 99.91, 107.81]
k7_total = [51.57, 56.84, 62.97, 72.33, 76.74, 77.98, 84.71, 95.03, 98.64, 106.5]

line_plot_general(x_values, k3_total, k5_total, k7_total, 'Encryption time')

# %% [markdown]
# ### Distances

# %%
x_values = list(range(8, 18))
k3_total = [126.29, 158.87, 189.95, 223.80, 260.21, 289.35, 302.71, 350.82, 401.08, 477.50]
k5_total = [123.53, 164.15, 186.09, 217.72, 259.31, 290.81, 289.55, 328.74, 424.49, 467.07]
k7_total = [124.22, 158.03, 185.21, 234.65, 263.84, 288.39, 287.05, 359.5, 424.04, 475.32]

line_plot_general(x_values, k3_total, k5_total, k7_total, 'Distances computation time')

# %% [markdown]
# ### Comparisons

# %%
x_values = list(range(8, 18))
k3_total = [896.72, 1346.66, 1691.99, 2410.46, 3045.39, 3742.85, 4771.19, 5928.94, 7184.19, 9217.18]
k5_total = [808.57, 1314.27, 1639.15, 2321.5, 2929.91, 3870.28, 4548.8, 5796.78, 7220.89, 9409.2]
k7_total = [897.11, 1299.24, 1750.43, 2495.93, 3229.59, 3670.73, 4552.67, 6126.68, 7236.6, 9317.52]

line_plot_general(x_values, k3_total, k5_total, k7_total, 'Comparisons computation time')

# %% [markdown]
# ### Sorting

# %%
x_values = list(range(8, 18))
k3_total = [537.80, 1057.84, 1643.92, 2813.97, 4355.43, 6690.94, 10344.59, 15406.11, 22740.85, 39087.76] 
k5_total = [511.89, 1064.16, 1619.96, 3406.56, 4158.76, 7000.32, 10244.8, 15023.9, 22849.4, 38881.3]
k7_total = [575.1, 1038.68, 1690.91, 2981.57, 4363.22, 6758.53, 10048.4, 16120, 22699.9, 38582.4]

line_plot_general(x_values, k3_total, k5_total, k7_total, 'Sorting time')
